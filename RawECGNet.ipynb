# %%
import os
import numpy as np
import pywt
import random
import seaborn as sns
import tensorflow as tf
from keras.layers import Add
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (
  Input, Conv1D, BatchNormalization, Activation, GlobalAveragePooling1D, 
  Dense, Dropout, GRU, Concatenate, LayerNormalization, MultiHeadAttention, 
  Reshape, Multiply, Softmax
)
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from utils import (
  encode_labels, check_gpu_availability, plot_loss_accuracytupian, 
  evaluate_model, plot_confusion_matrixtupian, plot_tsne, 
  plot_precision_recall_curve_multiclasstupian, plot_roc_curve_multiclasstupian, 
  AdjustLearningRateCallback, denoise2,count_labels,denoise2_iterative2,AdjustLearningRateCallback
)
from utils import plot_precision_recall_curve_multiclass,plot_roc_curve_multiclass2,calculate_g_mean,plot_confusion_matrix,plot_confusion_matrix2,plot_loss_accuracy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv1DTranspose
# Out:
# c:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.20.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
check_gpu_availability()
# Out:
# GPU 可用

# %%
# 加载数据
datafilename1 = "C:\\Users\\Administrator\\Desktop\\database\\cinc2017denoise.npz"
data1 = np.load(datafilename1, allow_pickle=True)
X_train, y_train, X_val, y_val, X_test, y_test = data1['ecgstrain'], data1['labelstrain'], data1['ecgsval'], data1['labelsval'], data1['ecgstest'], data1['labelstest']

# %%
y_train = encode_labels(y_train)
y_test = encode_labels(y_test)
y_val= encode_labels(y_val)
y_train = to_categorical(y_train, num_classes=4)
y_val=to_categorical(y_val, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer

class DSU(Layer):
    def __init__(self, output_dim, **kwargs):
        super(DSU, self).__init__(**kwargs)
        self.output_dim = output_dim

    def build(self, input_shape):
        # 创建一个权重矩阵，用于将稀疏输入转换为密集表示
        self.kernel = self.add_weight(name='kernel',
                                      shape=(input_shape[-1], self.output_dim),
                                      initializer='uniform',
                                      trainable=True)
        super(DSU, self).build(input_shape)

    def call(self, inputs):
        # 假设输入是一个稀疏矩阵
        # 使用权重矩阵对输入进行转换
        dense_output = tf.matmul(inputs, self.kernel)
        return dense_output

    def compute_output_shape(self, input_shape):
        # 输出形状为(batch_size, output_dim)
        return (input_shape[0], self.output_dim)

    def get_config(self):
        config = super(DSU, self).get_config()
        config.update({
            'output_dim': self.output_dim
        })
        return config

# %%
from tensorflow.keras.layers import Input, Conv1D, LayerNormalization, Activation, Dense, GlobalAveragePooling1D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.activations import gelu
import tensorflow as tf
def convnext_block_1d(x, filters, kernel_size, strides):
    shortcut = x
    # 主卷积路径
    x = Conv1D(filters, kernel_size, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(gelu)(x)
    x = Conv1D(filters, 7, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation(gelu)(x)
    x = Conv1D(filters, 3,padding='same')(x)
    x = BatchNormalization()(x)
    if shortcut.shape[-1] != x.shape[-1] or shortcut.shape[-2] != x.shape[-2]:
        shortcut = Conv1D(filters, 1, strides=strides, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    # 添加跳过连接
    x = Add()([x, shortcut])
    x = Activation(gelu)(x)
    return x
def convnext_1d(num_classes=4):
    input_1 = Input(shape=(4500, 1))
    x = Conv1D(32, 31, strides=2, padding='same')(input_1)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # Stacking ConvNeXt blocks for 1D with more layers and GELU activation
    x = convnext_block_1d(x, 32, 31, 2)  # (3000, 32)
    x = convnext_block_1d(x, 64, 17, 2)  # (1500, 64)
    x = convnext_block_1d(x, 128, 9, 2)  # (750, 128)
    x = convnext_block_1d(x, 128, 9, 1)  # Added an additional block with no stride change
    x = convnext_block_1d(x, 256, 5, 2)  # (375, 256)
    # Global Average Pooling as in typical ConvNeXt architectures, but for 1D
    x = GlobalAveragePooling1D()(x)
    x = Dense(256, activation='relu')(x)  # GELU activation in dense layer
    x = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=input_1, outputs=x)
    return model
model = convnext_1d()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4500, 1)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 2250, 32)     1024        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2250, 32)     128         conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 2250, 32)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1125, 32)     31776       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1125, 32)     128         conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1125, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1125, 32)     7200        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1125, 32)     128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1125, 32)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1125, 32)     3104        activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 1125, 32)     1056        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1125, 32)     128         conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1125, 32)     128         conv1d_4[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1125, 32)     0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1125, 32)     0           add[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 563, 64)      34880       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 563, 64)      256         conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 563, 64)      0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 563, 64)      28736       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 563, 64)      256         conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 563, 64)      0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 563, 64)      12352       activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 563, 64)      2112        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 563, 64)      256         conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 563, 64)      256         conv1d_8[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 563, 64)      0           batch_normalization_7[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 563, 64)      0           add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 282, 128)     73856       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 282, 128)     512         conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 282, 128)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 282, 128)     114816      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 282, 128)     512         conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 282, 128)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 282, 128)     49280       activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 282, 128)     8320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 282, 128)     512         conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 282, 128)     512         conv1d_12[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 282, 128)     0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 282, 128)     0           add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 282, 128)     147584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 282, 128)     512         conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 282, 128)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 282, 128)     114816      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 282, 128)     512         conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 282, 128)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 282, 128)     49280       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 282, 128)     512         conv1d_15[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 282, 128)     0           batch_normalization_15[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 282, 128)     0           add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 141, 256)     164096      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 141, 256)     1024        conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 141, 256)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 141, 256)     459008      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 141, 256)     1024        conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 141, 256)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 141, 256)     196864      activation_14[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 141, 256)     33024       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 141, 256)     1024        conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 141, 256)     1024        conv1d_19[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 141, 256)     0           batch_normalization_18[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 141, 256)     0           add_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 256)          0           activation_15[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          65792       global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            1028        dense[0][0]
# ==================================================================================================
# Total params: 1,609,348
# Trainable params: 1,604,676
# Non-trainable params: 4,672
# __________________________________________________________________________________________________

# %%
callback = AdjustLearningRateCallback(factor=0.1, patience=2, min_lr=1e-8)
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
history=model.fit(X_train, y_train, batch_size=256, epochs=80, validation_data=(X_val, y_val), callbacks=[callback,early_stopping])
# Out:
# Epoch 1/80
# 55/55 [==============================] - 25s 165ms/step - loss: 0.3219 - accuracy: 0.7013 - val_loss: 0.3518 - val_accuracy: 0.6567
# Epoch 2/80
# 55/55 [==============================] - 8s 140ms/step - loss: 0.2431 - accuracy: 0.7914 - val_loss: 0.6629 - val_accuracy: 0.3989
# Epoch 3/80
# 55/55 [==============================] - 8s 140ms/step - loss: 0.2199 - accuracy: 0.8170 - val_loss: 0.2598 - val_accuracy: 0.7842
# Epoch 4/80
# 55/55 [==============================] - 8s 140ms/step - loss: 0.2016 - accuracy: 0.8365 - val_loss: 0.2776 - val_accuracy: 0.7689
# Epoch 5/80
# 55/55 [==============================] - 8s 141ms/step - loss: 0.1962 - accuracy: 0.8428 - val_loss: 0.3681 - val_accuracy: 0.7134
# Reduced learning rate to 0.00010000000474974513.
# Epoch 6/80
# 55/55 [==============================] - 8s 141ms/step - loss: 0.1698 - accuracy: 0.8669 - val_loss: 0.2007 - val_accuracy: 0.8425
# Epoch 7/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1598 - accuracy: 0.8787 - val_loss: 0.1845 - val_accuracy: 0.8529
# Epoch 8/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1531 - accuracy: 0.8842 - val_loss: 0.1850 - val_accuracy: 0.8474
# Epoch 9/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1460 - accuracy: 0.8916 - val_loss: 0.1904 - val_accuracy: 0.8387
# Reduced learning rate to 1.0000000656873453e-05.
# Epoch 10/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1369 - accuracy: 0.8986 - val_loss: 0.1787 - val_accuracy: 0.8529
# Epoch 11/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1341 - accuracy: 0.9015 - val_loss: 0.1745 - val_accuracy: 0.8583
# Epoch 12/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1330 - accuracy: 0.9032 - val_loss: 0.1722 - val_accuracy: 0.8632
# Epoch 13/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1327 - accuracy: 0.9037 - val_loss: 0.1712 - val_accuracy: 0.8638
# Epoch 14/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1306 - accuracy: 0.9056 - val_loss: 0.1703 - val_accuracy: 0.8698
# Epoch 15/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1296 - accuracy: 0.9067 - val_loss: 0.1702 - val_accuracy: 0.8676
# Epoch 16/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1287 - accuracy: 0.9081 - val_loss: 0.1699 - val_accuracy: 0.8659
# Epoch 17/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1268 - accuracy: 0.9090 - val_loss: 0.1691 - val_accuracy: 0.8703
# Epoch 18/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1266 - accuracy: 0.9092 - val_loss: 0.1697 - val_accuracy: 0.8649
# Epoch 19/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1245 - accuracy: 0.9114 - val_loss: 0.1690 - val_accuracy: 0.8687
# Epoch 20/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1237 - accuracy: 0.9118 - val_loss: 0.1684 - val_accuracy: 0.8703
# Epoch 21/80
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1226 - accuracy: 0.9119 - val_loss: 0.1684 - val_accuracy: 0.8719
# Epoch 22/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1205 - accuracy: 0.9141 - val_loss: 0.1677 - val_accuracy: 0.8703
# Epoch 23/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1198 - accuracy: 0.9145 - val_loss: 0.1681 - val_accuracy: 0.8692
# Epoch 24/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1180 - accuracy: 0.9162 - val_loss: 0.1672 - val_accuracy: 0.8703
# Epoch 25/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1167 - accuracy: 0.9180 - val_loss: 0.1677 - val_accuracy: 0.8676
# Epoch 26/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1156 - accuracy: 0.9180 - val_loss: 0.1668 - val_accuracy: 0.8725
# Epoch 27/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1142 - accuracy: 0.9210 - val_loss: 0.1662 - val_accuracy: 0.8719
# Epoch 28/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1132 - accuracy: 0.9211 - val_loss: 0.1662 - val_accuracy: 0.8703
# Epoch 29/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1120 - accuracy: 0.9216 - val_loss: 0.1658 - val_accuracy: 0.8730
# Epoch 30/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1102 - accuracy: 0.9232 - val_loss: 0.1650 - val_accuracy: 0.8763
# Epoch 31/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1078 - accuracy: 0.9257 - val_loss: 0.1646 - val_accuracy: 0.8741
# Epoch 32/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1069 - accuracy: 0.9250 - val_loss: 0.1648 - val_accuracy: 0.8692
# Epoch 33/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1069 - accuracy: 0.9258 - val_loss: 0.1645 - val_accuracy: 0.8703
# Epoch 34/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1039 - accuracy: 0.9284 - val_loss: 0.1644 - val_accuracy: 0.8725
# Epoch 35/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1024 - accuracy: 0.9299 - val_loss: 0.1644 - val_accuracy: 0.8719
# Epoch 36/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1014 - accuracy: 0.9298 - val_loss: 0.1633 - val_accuracy: 0.8730
# Epoch 37/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0994 - accuracy: 0.9332 - val_loss: 0.1634 - val_accuracy: 0.8752
# Epoch 38/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0980 - accuracy: 0.9336 - val_loss: 0.1650 - val_accuracy: 0.8725
# Reduced learning rate to 1.0000001111620804e-06.
# Epoch 39/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0955 - accuracy: 0.9356 - val_loss: 0.1638 - val_accuracy: 0.8736
# Epoch 40/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0960 - accuracy: 0.9354 - val_loss: 0.1635 - val_accuracy: 0.8730
# Reduced learning rate to 1.0000001537946446e-07.
# Epoch 41/80
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0954 - accuracy: 0.9364 - val_loss: 0.1635 - val_accuracy: 0.8730

# %%
evaluate_model(model,X_test,y_test)
# Out:
# Precision: 0.8101726296494344
# Recall: 0.7875441491822726
# F1 Score: 0.7977728296191913
# Accuracy: 0.8829444891391794
# Class 1 - Precision: 0.8782608695652174, Recall: 0.8898678414096917, F1 Score: 0.8840262582056894
# Class 2 - Precision: 0.9001907183725365, Recall: 0.9433710859427049, F1 Score: 0.9212752114508783
# Class 3 - Precision: 0.8511278195488722, Recall: 0.7669376693766937, F1 Score: 0.8068424803991447
# Class 4 - Precision: 0.6111111111111112, Recall: 0.55, F1 Score: 0.5789473684210527
# Class 1 Accuracy: 0.9786806114239742
# Class 2 Accuracy: 0.9026548672566371
# Class 3 Accuracy: 0.8909895414320194
# Class 4 Accuracy: 0.9935639581657281

# %%
y_pred_classes = np.argmax(model.predict(X_test), axis=-1)
y_test_classes = np.argmax(y_test, axis=1)

# %%
plot_confusion_matrix2(y_test_classes, y_pred_classes, classes=['A', 'N', 'O', '~'])
