# %%
import os
import numpy as np
import pywt
import random
import seaborn as sns
import tensorflow as tf
from keras.layers import Add
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (
  Input, Conv1D, BatchNormalization, Activation, GlobalAveragePooling1D, 
  Dense, Dropout, GRU, Concatenate, LayerNormalization, MultiHeadAttention, 
  Reshape, Multiply, Softmax
)
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from utils import (
  encode_labels, check_gpu_availability, plot_loss_accuracytupian, 
  evaluate_model, plot_confusion_matrixtupian, plot_tsne, 
  plot_precision_recall_curve_multiclasstupian, plot_roc_curve_multiclasstupian, 
  AdjustLearningRateCallback, denoise2,count_labels,denoise2_iterative2,AdjustLearningRateCallback
)
from utils import plot_precision_recall_curve_multiclass,plot_roc_curve_multiclass2,calculate_g_mean,plot_confusion_matrix,plot_confusion_matrix2,plot_loss_accuracy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv1DTranspose
# Out:
# c:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.20.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
check_gpu_availability()
# Out:
# GPU 可用

# %%
# 加载数据
datafilename1 = "C:\\Users\\Administrator\\Desktop\\MFEG\\dataprocessing\\cinc2017denoise.npz"
data1 = np.load(datafilename1, allow_pickle=True)
X_train, y_train, X_val, y_val, X_test, y_test = data1['ecgstrain'], data1['labelstrain'], data1['ecgsval'], data1['labelsval'], data1['ecgstest'], data1['labelstest']

# %%
y_train = encode_labels(y_train)
y_test = encode_labels(y_test)
y_val= encode_labels(y_val)
y_train = to_categorical(y_train, num_classes=4)
y_val=to_categorical(y_val, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, Add, GlobalAveragePooling1D, Dropout, Dense
from tensorflow.keras.models import Model

def residual_block(x, filters, kernel_size, strides):
    shortcut = x
    # 主卷积路径
    x = Conv1D(filters, kernel_size, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv1D(filters, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)

    # 如果shortcut的形状与x不匹配，则调整shortcut
    if shortcut.shape[-1] != x.shape[-1] or shortcut.shape[-2] != x.shape[-2]:
        shortcut = Conv1D(filters, 1, strides=strides, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    # 添加跳过连接
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

def resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv1D(32, 3, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = residual_block(x, 32, 3, 2)
    x = residual_block(x, 64, 3, 2)
    x = residual_block(x, 128,3, 2)
    x = residual_block(x, 256,3, 2)
    x=GlobalAveragePooling1D()(x)
    x = Dropout(0.1)(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=x)
    return model

# Example usage:
model =resnet((4500, 1), 4)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4500, 1)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 2250, 32)     128         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 2250, 32)     128         conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 2250, 32)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 1125, 32)     3104        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1125, 32)     128         conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1125, 32)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1125, 32)     3104        activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1125, 32)     1056        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1125, 32)     128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1125, 32)     128         conv1d_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1125, 32)     0           batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1125, 32)     0           add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 563, 64)      6208        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 563, 64)      256         conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 563, 64)      0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 563, 64)      12352       activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 563, 64)      2112        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 563, 64)      256         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 563, 64)      256         conv1d_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 563, 64)      0           batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 563, 64)      0           add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 282, 128)     24704       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 282, 128)     512         conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 282, 128)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 282, 128)     49280       activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 282, 128)     8320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 282, 128)     512         conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 282, 128)     512         conv1d_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 282, 128)     0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 282, 128)     0           add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 141, 256)     98560       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 141, 256)     1024        conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 141, 256)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 141, 256)     196864      activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 141, 256)     33024       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 141, 256)     1024        conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 141, 256)     1024        conv1d_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 141, 256)     0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 141, 256)     0           add_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 256)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            1028        dropout[0][0]
# ==================================================================================================
# Total params: 445,732
# Trainable params: 442,788
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
callback = AdjustLearningRateCallback(factor=0.1, patience=2, min_lr=1e-8)
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
history=model.fit(X_train, y_train, batch_size=256, epochs=80, validation_data=(X_val, y_val), callbacks=[callback,early_stopping])
# Out:
# Epoch 1/80
# 55/55 [==============================] - 15s 90ms/step - loss: 0.4011 - accuracy: 0.6041 - val_loss: 0.4659 - val_accuracy: 0.5896
# Epoch 2/80
# 55/55 [==============================] - 3s 64ms/step - loss: 0.3411 - accuracy: 0.6703 - val_loss: 0.3806 - val_accuracy: 0.6469
# Epoch 3/80
# 55/55 [==============================] - 3s 63ms/step - loss: 0.3158 - accuracy: 0.7069 - val_loss: 0.3418 - val_accuracy: 0.6670
# Epoch 4/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.3024 - accuracy: 0.7225 - val_loss: 0.3301 - val_accuracy: 0.7117
# Epoch 5/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2904 - accuracy: 0.7397 - val_loss: 0.4146 - val_accuracy: 0.5553
# Epoch 6/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2856 - accuracy: 0.7441 - val_loss: 0.3020 - val_accuracy: 0.7302
# Epoch 7/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2754 - accuracy: 0.7556 - val_loss: 0.3130 - val_accuracy: 0.7308
# Epoch 8/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2687 - accuracy: 0.7639 - val_loss: 0.3171 - val_accuracy: 0.7357
# Reduced learning rate to 0.00010000000474974513.
# Epoch 9/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2484 - accuracy: 0.7845 - val_loss: 0.2733 - val_accuracy: 0.7591
# Epoch 10/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2410 - accuracy: 0.7989 - val_loss: 0.2689 - val_accuracy: 0.7815
# Epoch 11/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2371 - accuracy: 0.8022 - val_loss: 0.2646 - val_accuracy: 0.7782
# Epoch 12/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2342 - accuracy: 0.8046 - val_loss: 0.2638 - val_accuracy: 0.7837
# Epoch 13/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2300 - accuracy: 0.8081 - val_loss: 0.2719 - val_accuracy: 0.7831
# Epoch 14/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2284 - accuracy: 0.8108 - val_loss: 0.2609 - val_accuracy: 0.7913
# Epoch 15/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2241 - accuracy: 0.8179 - val_loss: 0.2665 - val_accuracy: 0.7940
# Epoch 16/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2220 - accuracy: 0.8167 - val_loss: 0.2791 - val_accuracy: 0.7700
# Reduced learning rate to 1.0000000656873453e-05.
# Epoch 17/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2157 - accuracy: 0.8259 - val_loss: 0.2550 - val_accuracy: 0.7929
# Epoch 18/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2141 - accuracy: 0.8274 - val_loss: 0.2541 - val_accuracy: 0.7946
# Epoch 19/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2144 - accuracy: 0.8252 - val_loss: 0.2527 - val_accuracy: 0.7913
# Epoch 20/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2143 - accuracy: 0.8256 - val_loss: 0.2524 - val_accuracy: 0.7924
# Epoch 21/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2129 - accuracy: 0.8274 - val_loss: 0.2522 - val_accuracy: 0.7935
# Epoch 22/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2126 - accuracy: 0.8302 - val_loss: 0.2518 - val_accuracy: 0.7935
# Epoch 23/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2124 - accuracy: 0.8330 - val_loss: 0.2519 - val_accuracy: 0.7940
# Epoch 24/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2118 - accuracy: 0.8311 - val_loss: 0.2522 - val_accuracy: 0.7951
# Reduced learning rate to 1.0000001111620804e-06.
# Epoch 25/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2117 - accuracy: 0.8312 - val_loss: 0.2517 - val_accuracy: 0.7924
# Epoch 26/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2111 - accuracy: 0.8304 - val_loss: 0.2516 - val_accuracy: 0.7913
# Epoch 27/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2116 - accuracy: 0.8301 - val_loss: 0.2516 - val_accuracy: 0.7918
# Epoch 28/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2111 - accuracy: 0.8320 - val_loss: 0.2516 - val_accuracy: 0.7918
# Epoch 29/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2119 - accuracy: 0.8302 - val_loss: 0.2516 - val_accuracy: 0.7924
# Reduced learning rate to 1.0000001537946446e-07.
# Epoch 30/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2113 - accuracy: 0.8321 - val_loss: 0.2515 - val_accuracy: 0.7918
# Epoch 31/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2114 - accuracy: 0.8316 - val_loss: 0.2515 - val_accuracy: 0.7924
# Epoch 32/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2110 - accuracy: 0.8320 - val_loss: 0.2515 - val_accuracy: 0.7924
# Epoch 33/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2107 - accuracy: 0.8327 - val_loss: 0.2515 - val_accuracy: 0.7924
# Epoch 34/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2115 - accuracy: 0.8299 - val_loss: 0.2515 - val_accuracy: 0.7924
# Epoch 35/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2114 - accuracy: 0.8331 - val_loss: 0.2515 - val_accuracy: 0.7924
# Epoch 36/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2114 - accuracy: 0.8304 - val_loss: 0.2515 - val_accuracy: 0.7924
# Reduced learning rate to 1.000000171558213e-08.
# Epoch 37/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2117 - accuracy: 0.8304 - val_loss: 0.2515 - val_accuracy: 0.7918
# Epoch 38/80
# 55/55 [==============================] - 4s 64ms/step - loss: 0.2108 - accuracy: 0.8329 - val_loss: 0.2515 - val_accuracy: 0.7918
# Reduced learning rate to 1e-08.
# Epoch 39/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2117 - accuracy: 0.8303 - val_loss: 0.2515 - val_accuracy: 0.7924
# Epoch 40/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2108 - accuracy: 0.8328 - val_loss: 0.2515 - val_accuracy: 0.7924
# Epoch 41/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2121 - accuracy: 0.8299 - val_loss: 0.2515 - val_accuracy: 0.7924
# Reduced learning rate to 1e-08.
# Epoch 42/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2113 - accuracy: 0.8316 - val_loss: 0.2515 - val_accuracy: 0.7924
# Epoch 43/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2110 - accuracy: 0.8317 - val_loss: 0.2515 - val_accuracy: 0.7924
# Reduced learning rate to 1e-08.
# Epoch 44/80
# 55/55 [==============================] - 4s 65ms/step - loss: 0.2114 - accuracy: 0.8304 - val_loss: 0.2515 - val_accuracy: 0.7924

# %%
evaluate_model(model,X_test,y_test)
# Out:
# Precision: 0.8443052199489773
# Recall: 0.6645767163346558
# F1 Score: 0.7181185474309113
# Accuracy: 0.8016894609814964
# Class 1 - Precision: 0.8037383177570093, Recall: 0.7577092511013216, F1 Score: 0.780045351473923
# Class 2 - Precision: 0.8145539906103286, Recall: 0.9247168554297135, F1 Score: 0.8661466458658347
# Class 3 - Precision: 0.7589285714285714, Recall: 0.575880758807588, F1 Score: 0.6548536209553159
# Class 4 - Precision: 1.0, Recall: 0.4, F1 Score: 0.5714285714285715
# Class 1 Accuracy: 0.9609814963797265
# Class 2 Accuracy: 0.827433628318584
# Class 3 Accuracy: 0.8197908286403862
# Class 4 Accuracy: 0.995172968624296

# %%
y_pred_classes = np.argmax(model.predict(X_test), axis=-1)
y_test_classes = np.argmax(y_test, axis=1)

# %%
plot_confusion_matrix2(y_test_classes, y_pred_classes, classes=['A', 'N', 'O', '~'])
